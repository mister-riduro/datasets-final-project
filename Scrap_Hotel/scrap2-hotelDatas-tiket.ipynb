# %%
check_out = "2022-09-26"
check_in = "2022-09-27"

# %%
# Jawa Timur
link_hotel = [
    #Surabaya
    f"https://www.tiket.com/hotel/indonesia/maxonehotels-at-dharmahusada-surabaya-108001534490348837?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/d-carol-hotel-surabaya-412001639107378535?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/choice-city-hotel-108001534490376040?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/g-suites-surabaya-by-amithya-108001534490324500?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/royal-regantris-cendana-formerly-royal-singosari-cendana-504001648799533674?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/livinn-taman-melati-surabaya-410001633025234697?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-great-diponegoro-surabaya-402001613719815965?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/arimbi-stay-412001639107218351?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/cleo-hotel-basuki-rahmat-surabaya-412001639641650556?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/aston-inn-jemursari-408001628583494550?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/varna-culture-hotel-tunjungan-surabaya-108001534490321068?checkin={check_in}&checkout={check_out}&room=1&adult=1",
    f"https://www.tiket.com/hotel/indonesia/djuragan-kamar-gunung-anyar-304001588132130240?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bekizaar-hotel-surabaya-108001534490327411?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/halogen-hotel-108001534490312995?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/horison-express-quds-royal-surabaya-108001534490290420?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/life-hotel-stasiun-kota-surabaya-501001643258729514?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/best-hotel-surabaya-506001655872240714?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bisanta-bidakara-surabaya-412001639993336479?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/kampi-hotel-tunjungan-surabaya-502001644543927840?checkin={check_in}&checkout={check_out}&room=1&adult=1",
    f"https://www.tiket.com/hotel/indonesia/hersya-front-one-inn-surabaya-108001534490383311?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/the-win-hotel-surabaya-108001534490324734?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/tab-hotel-108001534490304089?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-oval-surabaya-108001534490291139?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-plus-near-stasiun-tvri-surabaya-2-312001608714911868?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ibis-surabaya-city-center-412001639677721203?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/life-taman-melati-surabaya-404001617431420381?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/prime-royal-boutique-hotel-surabaya-108001534490266877?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/batiqa-hotel-darmo-surabaya-201001548132584626?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-utami-surabaya-108001534490321795?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/sans-hotel-rajawali-surabaya-412001639108063381?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-tilamas-108001534490322267?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false"

    #Malang
    f"https://www.tiket.com/hotel/indonesia/favehotel-malang-404001617246031513?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bambam-house-syariah-402001612240355635?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/whiz-prime-hotel-basuki-rahmat-malang-108001534490359890?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1289-cbr-residence-210001570953625303?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-alun-alun-batu-2-504001651130174094?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/maxone-ascent-hotel-malang-108001534490323335?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bayleaf-guest-house-syariah-502001644841877195?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/my-dormy-hostel-umm-501001642475865000?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ibis-styles-malang-504001650525083809?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-mitra-guest-house-505001651732361945?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/pohon-inn-108001534490308395?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/grand-kadaka-syariah-204001554310851672?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/grand-dream-cita-mandiri-syariah-311001605518369656?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/gangnam-hotel-near-mall-olympic-garden-malang-504001649830597693?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-syariah-99-409001630487727673?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/front-one-budget-malang-by-azana-401001609821910185?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/sans-hotel-queen-batu-503001646125357589?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/so-boutique-hostel-206001561722041151?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-90396-the-halona-villa-batu-412001639107891967?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-3298-bromo-guest-house-family-412001639107857960?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/lg-homestay-303001583412220820?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Probolinggo
    f"https://www.tiket.com/hotel/indonesia/ancala-inn-504001650441644526?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-cemara-indah-108001534490292665?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/gubuk-ndeso-homestay-201001547180296780?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/grand-whiz-hotel-bromo-501001641893025501?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1087-homestay-potato-house-207001563427356520?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/istana-petani-homestay-bromo-412001639986780409?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/defada-village-bromo-at-desa-wisata-bromo-506001656058614064?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bromo-indah-lestari-homestay-redpartner-412001639107285767?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/savana-guesthouse-108001534490326152?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/tengger-homestay-bromo-410001634106668396?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-nur-cahaya-syariah-309001599647113030?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ben-hill-redpartner-412001639107262986?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/yeski-homestay-at-desa-wisata-bromo-411001636538453918?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/sri-dewi-homestay-redpartner-502001643878846626?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/good-karma-guesthouse-412001638920492853?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/spot-on-2327-dome-hotel-212001576226724634?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/villa-wijayanti-bromo-412001639108254974?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/villa-tengger-asri-6-gunung-bromo-402001614219782115?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-firdaus-bromo-208001566360010029?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/anugrah-bromo-homestay-at-desa-wisata-bromo-504001649524196648?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/gebby-homestay-bromo-redpartner-411001637137888953?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-family-gunung-bromo-412001638664503072?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Banyuwangi
    f"https://www.tiket.com/hotel/indonesia/room-hostel-banyuwangi-412001638848796884?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1579-kateel-inn-209001569301213354?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-jenderal-ahmad-yani-banyuwangi-211001573202724399?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-near-mall-roxy-banyuwangi-2-206001560509952476?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/samar-wulu-guest-house-syariah-412001639975006679?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/spot-on-2022-darman-family-residence-401001610506424536?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/berlian-abadi-hotel-108001534519776966?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-plus-near-banyuwangi-airport-505001653382855748?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-pantai-boom-210001571643922054?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-banyuwangi-kota-train-station-312001607911828542?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/art-doorz-homestay-istana-gandrung-408001627873237081?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/majapahit-syariah-309001600829111122?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/snooze-ijen-309001599646876699?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/mango-tree-homestay-505001652859924669?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/urbanview-hotel-kumala-banyuwangi-508001660557932101?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-near-untag-banyuwangi-206001559549830969?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-anugerah-bondowoso-502001644995823926?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/grand-hotel-bondowoso-412001639976784845?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Lumajang
    f"https://www.tiket.com/hotel/indonesia/express-o-91370-rumah-pemandangan-semeru-asli-507001656645706506?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/omah-guest-house-412001638593836419?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/tumpaksewu-homestay-301001579896388473?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/dcorner-tumpaksewu-homestay-506001654747532026?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/tumpak-sewu-guest-house-412001638406811216?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Pacitan
    f"https://www.tiket.com/hotel/indonesia/oyo-942-srikandi-hotel-205001558717237944?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1565-hotel-homiko-209001567672207632?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-arsyana-312001607049011016?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-letjend-s-parman-pacitan-410001633439650732?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-91201-larasati-homestay-pantai-klayar-506001655953238400?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-bundo-permai-1-301001579900762969?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-griya-soeratin-pacitan-506001655112628327?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1190-griya-soeratin-residence-208001565239505938?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/vh-surf-camp-402001614183543477?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2643-hotel-graha-prima-301001578022207980?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-near-alun-alun-pacitan-2-504001650878347335?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false"
]

print(len(link_hotel))
# Out:
# 107

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price):
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)

      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)

      for c in range(len(room_price)):
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude']) 
df.index += 149

df

# len(minPrice)
# Out:
#                                            Hotel Image  \
# 149  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 150  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 151  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 152  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 153  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ..                                                 ...
# 242  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 243  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 244  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 245  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 246  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
#
#                                             Hotel Name Tipe Properti  \
# 149              MaxoneHotels at Dharmahusada Surabaya         Hotel
# 150                             D Carol Hotel Surabaya         Hotel
# 151                                  Choice City Hotel         Hotel
# ...

# %%
df.to_csv('db_hotel_jatim.csv', index=True, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
