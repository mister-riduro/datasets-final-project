checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-plus-near-ancol-208001565691308047?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/stay-inn-hostel-jakarta-209001568715307737?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-kota-tua-2-412001639108010495?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/heritel-urban-hostel-412001639107534903?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/madu-inn-hotel-306001593161288663?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/grace-residences-glodok-412001639107477014?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/senyaman-hotel-redpartner-502001644471936133?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-mutiara-kota-tua-506001654224068491?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/nusalink-antoni-near-hayam-wuruk-412001639107843924?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/urbanview-hotel-casa-kota-mangga-besar-509001662048999389?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/new-purri-melati-hotel-redpartner-506001654519267384?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-sanrina-506001655332585799?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
]

print(len(link_hotel))
# Out:
# 66

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price):
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)

      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)

      for c in range(len(room_price)):
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\College\final-project\Datasets\Scrap_Hotel\scrap2-hotelDatas-tiket.ipynb Cell 4 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap2-hotelDatas-tiket.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> url=link_hotel[i]
#      <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap2-hotelDatas-tiket.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a> # print(url)
# ---> <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap2-hotelDatas-tiket.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> req=requests.get(url)
#      <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap2-hotelDatas-tiket.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> content=req.text
# ...

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude']) 
df.index += 403

df

# len(minPrice)
# Out:
#                                            Hotel Image  \
# 349  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 350  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 351  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 352  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 353  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 354  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 355  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 356  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 357  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 358  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 359  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 360  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 361  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 362  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 363  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 364  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ...

# %%
df.to_csv('db_hotel_jakarta.csv', index=True, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
