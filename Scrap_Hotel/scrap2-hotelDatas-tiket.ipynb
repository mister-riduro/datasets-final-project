checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ultima-syariah-cipanas-garut-redpartner-412001639108211618?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/container-hotel-507001658475107229?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-resort-near-darajat-garut-407001626925826002?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-otista-garut-206001560509888428?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/wisma-vandera-syariah-garut-redpartner-505001652415331261?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-pataruman-garut-206001560509738240?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/green-patriot-resort-407001625727762152?checkin={check_in}&checkout={check_out}&room=1&adult=1",
    f"https://www.tiket.com/hotel/indonesia/g-double-l-505001652103920290?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/darajat-4r-cottage-syariah-310001602136883794?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hazza-homestay-syariah-412001639107532705?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-premium-joglo-garut-cottage-syariah-502001645587873381?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/spot-on-90921-wisma-pkpn-2-502001645168266531?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Bandung
    f"https://www.tiket.com/hotel/indonesia/yokotel-city-310001603794277232?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2562-pondok-tajlibu-syifa-syariah-411001638248914775?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bobobox-paskal-501001641446137753?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/rumah-tamu-ciumbuleuit-309001599533111292?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/temmu-coliving-202001549904413078?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-rumah-tawa-syariah-412001639989209861?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ruby-hotel-syariah-412001639108041399?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/shakti-capsule-cihampelas-bandung-412001639117913095?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/stay-inn-bandung-412001639108106305?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/cherry-homes-hotel-residence-108001534490291485?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ottenville-boutique-hotel-108001534490307677?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/alam-permai-hotel-108001534490373254?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/smart-capsule-by-buton-310001603175413088?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/andelir-hotel-bandung-202001551149708438?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/rooms-inc-btc-bandung-508001661409428194?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/amaryllis-hotels-306001591950280799?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-bumi-asih-gedung-sate-bandung-412001639985941753?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/wirton-hotel-109001537352175371?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/sapadia-guest-house-412001639989428083?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/cherry-homes-express-hotel-108001534490354465?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-sabang-bandung-212001577075410158?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ct-195-212001576827909927?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bantal-guling-trans-412001639107251600?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/ariandri-boutique-hotel-411001638243134139?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-flagship-90641-sky-city-home-412001639107898982?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-lotus-bandung-108001534490287561?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/budi-house-food-station-108001534490356398?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-cihampelas-2-108001534490267000?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-citradream-bandung-112001545304305417?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-flagship-91295-suria-city-hotel-syariah-506001654669856410?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/raffleshom-hotel-201001546865445082?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/sari-ater-hotel-resort-412001639879257264?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2141-pondok-pulo-sari-2-212001575876608258?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-3040-dpineapple-villa-302001581420618708?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/kanaka-residence-redpartner-507001658478665588?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bantal-guling-villa-lembang-108001534490328208?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-bumi-makmur-indah-412001639978391839?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-lembang-park-zoo-412001639108010522?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
]

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price):
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)

      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)

      for c in range(len(room_price)):
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude']) 
df.index += 251

df

# len(minPrice)
# Out:
#                                            Hotel Image  \
# 100  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 101  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 102  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 103  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 104  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ..                                                 ...
# 246  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 247  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 248  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 249  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 250  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
#
#                                             Hotel Name Tipe Properti  \
# 100                                  Charaka Residence         Hotel
# 101                                Turu Hostel Syariah      Homestay
# 102  RedDoorz Syariah near Komplek Candi Arjuna Die...   Guest House
# ...

# %%
df.to_csv('db_hotel_jabar.csv', index=True, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
