checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/yunna-express-411001638104693241?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-andalas-asri-308001598574637423?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/cendrawasih-syariah-homestay-211001573101913015?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/rumah-pahoman-syariah-redpartner-412001639987334233?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-pelangi-206001560503534058?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2990-z-syariah-homestay-302001580968817500?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2176-amanah-syariah-residence-212001575537306643?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-taman-merdeka-metro-lampung-309001600252213503?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2246-anjung-bang-oking-hotel-resort-212001577166306158?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-universitas-saburai-lampung-310001603714511698?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-syariah-near-hajimena-lampung-412001639108008104?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-politeknik-negeri-lampung-412001639108010957?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hani-guesthouse-410001635406690869?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-dwipa-wisata-hotel-407001625220930315?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-asri-syariah-tulang-bawang-barat-redpartner-412001639107550045?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-universitas-muhammadiyah-pringsewu-501001642694469208?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-jalan-sultan-agung-lampung-501001641541541588?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-90659-griya-tentrem-syariah-412001639107896686?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-3774-orchid-37-syariah-guest-house-412001639107865789?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/aksara-homestay-syariah-redpartner-411001638253960360?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-3695-33-avenue-412001639107863783?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-90124-oemah-ratu-hostel-syariah-412001639107881640?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/wisma-pringgondani-lampung-timur-redpartner-501001641195283014?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-exit-tol-kotabaru-itera-lampung-412001639108010024?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/urbanview-hotel-st-faustina-lampung-505001653639340243?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-cahaya-lampung-timur-redpartner-501001642434381451?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-syariah-way-jepara-lampung-timur-redpartner-501001641966345152?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/atta-guest-house-lampung-timur-redpartner-501001641361532257?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hevn-homestay-504001649657348825?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-griya-aulia-502001643858123893?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/hotel-sariami-redpartner-502001644894945220?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bintang-dieng-homestay-syariah-redpartner-502001643878846933?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-mahani-1-411001638180153508?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/spot-on-91306-bae-homestay-syariah-506001654743705197?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-pakde-2-501001642136299872?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-hambubun-501001642483836935?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/losmen-karang-besi-502001643858123944?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-tukimin-504001651214731152?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/losmen-src-joni-504001650966327687?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/aksara-homestay-506001656227908835?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/losmen-palmita-506001654818993743?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-andatu-by-desa-wisata-way-kambas-505001653847236936?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-plang-ijo-by-desa-wisata-way-kambas-505001653846332064?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/urbanview-hotel-bong-gajah-lampung-509001663325150698?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/bintang-dieng-homestay-syariah-redpartner-506001655121327827?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/express-o-91371-wisma-nadira-507001656645706700?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-jihan-by-desa-wisata-way-kambas-507001657300301973?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/aksara-homestay-syariah-redpartner-509001662940503615?checkin={check_in}&checkout={check_out}&room=1&adult=2&soldOut=false",
]

print(len(link_hotel))
# Out:
# 248

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price):
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)

      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)

      for c in range(len(room_price)):
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude']) 
df.index += 1801

df

# len(minPrice)
# Out:
#                                             Hotel Image  \
# 1564  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1565  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1566  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1567  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1568  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ...                                                 ...
# 1796  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1797  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1798  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1799  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1800  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
#
#                                      Hotel Name  Tipe Properti  \
# 1564                       Cordela Inn Bengkulu          Hotel
# 1565                    Jodipati Hotel Bengkulu          Hotel
# 1566                 Djo Front One Inn Bengkulu          Hotel
# ...

# %%
df.to_csv('db_hotel_kalimantan.csv', index=True, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
