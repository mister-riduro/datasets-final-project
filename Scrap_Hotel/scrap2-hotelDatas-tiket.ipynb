checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/quattrick-dee-homestay-redpartner-411001637316959615?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/quattrick-dee-homestay-207001563427355931?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/city-home-stay-506001654241431199?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/city-homestay-509001662802642845?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/arborek-homestay-403001617079051325?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-near-dermaga-pelabuhan-rakyat-504001651133728962?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",

    "https://www.tiket.com/hotel/indonesia/parkside-star-hotel-waena-507001657085816563?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/homestay-cartensz-506001654854475320?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hotel-yasmin-jayapura-112001544425602993?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-near-pelabuhan-jayapura-303001584962112614?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/sunnyday-inn-merauke-by-naraya-505001653792413516?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/votel-galaxy-hotel-abepura-303001583118013338?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hotel-surya-jaya-501001643625042014?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/sunny-day-inn-509001663646440897?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-merauke-city-center-504001650878346804?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hotel-gamalama-509001662856333395?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-waena-jayapura-501001641281491916?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hotel-ratna-manunggal-412001640764923841?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-abemoch-kampkey-502001645168268199?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-syariah-near-sentani-city-square-502001643966120886?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-cigombong-503001647510012892?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/patmos-hostel-sentani-206001561721334485?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/unity-roomrent-505001653973260704?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-jalan-cendrawasih-timika-303001584962112561?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-jalan-gelanggang-remaja-waena-jayapura-508001659528111384?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-merauke-city-center-509001663321052637?checkin=2022-10-03&checkout=2022-10-04&room=1&adult=2&soldOut=false",
]

print(len(link_hotel))
# Out:
# 77

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price):
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)

      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)

      for c in range(len(room_price)):
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude']) 
df.index += 1983

df

# len(minPrice)
# Out:
#                                             Hotel Image  \
# 1983  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1984  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1985  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1986  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1987  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1988  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1989  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1990  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1991  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1992  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1993  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1994  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1995  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1996  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1997  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 1998  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ...

# %%
df.to_csv('db_hotel_papuamaluku.csv', index=True, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
