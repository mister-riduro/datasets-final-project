checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/harmony-residence-tabanan-506001655339192611?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/ayudia-camp-507001658122231401?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/oyo-90714-umah-pande-tabanan-411001637903731481?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/teras-subak-jatiluwih-301001579887139876?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/umah-hijau-tabanan-307001593589743632?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/apple-villa-303001583407043557?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/bali-home-stay-spa-heritage-407001627453859698?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/tegal-jero-homestay-204001556125236223?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/buana-asti-homestay-108001534490381064?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/bukit-kembar-guest-house-206001560499449403?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/keyeh-homestay-311001604437186475?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/suweden-homestay-306001593178791631?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hara-bali-eco-homestay-310001603791434241?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/pondok-balian-303001583317723589?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/teras-subak-homestay-210001570694424147?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/pelangi-homestay-redpartner-505001653893914465?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/anish-homestay-506001655879515033?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/wanagiri-campsite-506001656276521139?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/tang-ting-tung-homestay-506001655420444350?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/vila-puspa-couple-509001662302386214?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/the-dewata-homestay-506001655419540973?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=2&soldOut=false",
]

print(len(link_hotel))
# Out:
# 167

# %%
from decimal import Decimal
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
room_price = ''
tempStr = ''
maxPrice = []
minPrice = []
cityHotel = []
addressHotel = []
hotelName = []
facilities = []
hotelRating = []
lattitude = []
longitude = []
hotelImage = []
propertyType = []
hotelLink = []
mapLink = []
wifi = 'wifi'


for i in range(0, len(link_hotel)):
  priceHotel = []
  url=link_hotel[i]

  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):

    room_price = a.findAll('div', attrs={'class':'room-price'})
    hotel_name = a.find('h1', attrs={'class':'property-name tix-font h4 line-clamp-2'})
    address_hotel = a.find('div', attrs={'class' : 'location-address'})
    city_hotel = a.find('div', attrs={'class' : 'location ellipsis'})
    hotel_rating = a.find('div', attrs={'class' : 'score tiket'})
    image_map = a.find('div', attrs={'class' : 'location-map'})
    image_hotel_div = a.find('div', attrs={'class' : 'image'})
    property_type = a.find('div', attrs={'class' : 'property-type'})

    # i = 0
    if len(room_price) > 0:
      hotelName.append(hotel_name.text)

      city_hotel = city_hotel.text.replace(',', '')
      cityHotel.append(city_hotel)
      hotelLink.append(link_hotel[i])
      # print(image_hotel_div)

      if image_hotel_div is None:
        image_hotel_default = a.find('div', attrs={'class' : 'photo-default'})
        image_hotel = image_hotel_default.find('img')
        image_hotel = image_hotel.get('src')
        image_hotel = "https://www.tiket.com/"+image_hotel
        hotelImage.append(image_hotel)
      else:
        image_hotel = image_hotel_div.find('img')
        image_hotel = image_hotel.get('src')
        hotelImage.append(image_hotel)

      address_hotel = address_hotel.find('div', attrs={'class' : 'line-clamp-2'})
      address_hotel = address_hotel.text.replace(',','.')
      addressHotel.append(address_hotel)

      propertyType.append(property_type.text)

      if hotel_rating is None:
        hotelRating.append("Belum ada rating")
      else:  
        hotelRating.append(hotel_rating.text)

      #GET IMAGE LINK
      image_map = image_map.find('img')
      map_link = image_map.get('src')
      mapLink.append(map_link)

      #ADJUST IMAGE LINK
      lat, long = map_link.split("|")[2].split(",")

      lat = Decimal(lat)
      long = Decimal(long)

      lattitude.append(lat)
      longitude.append(long)

      # Facilities
      # facil = a.findAll('div', attrs={'class':'facility-label'})
      # for b, data in enumerate(facil):
      #   facil[b] = data.text
      # facilities.append(facil)
      # print(i)
      # print(room_price)
      for c in range(len(room_price)):
        
        tempStr = room_price[c].find('span').text
        tempStr = tempStr.strip()
        tempStr = tempStr.lstrip('IDR ')
        tempStr = tempStr.replace('.', '')
        price = int(tempStr)
        priceHotel.append(price)
      maxPrice.append(max(priceHotel))
      minPrice.append(min(priceHotel))

    else:
      continue

# %%
# print(type(minPrice))

# df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice,facilities, lattitude, longitude)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Facilities', 'Lattitute', 'Longitude']) 
# df

df = pd.DataFrame(list(zip(hotelImage, hotelName, propertyType, cityHotel, addressHotel, hotelRating, minPrice, maxPrice, lattitude, longitude, mapLink, hotelLink)), columns =['Hotel Image', 'Hotel Name', 'Tipe Properti','City', 'Address', 'Hotel Rating', 'Min', 'Max', 'Lattitute', 'Longitude', 'Map Link', 'Hotel Link']) 
df.index += 431

df

# len(minPrice)
# Out:
#                                            Hotel Image  \
# 431  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 432  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 433  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 434  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 435  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# ..                                                 ...
# 572  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 573  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 574  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 575  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
# 576  https://s-light.tiket.photos/t/01E25EBZS3W0FY9...
#
#                                     Hotel Name  Tipe Properti  \
# 431                                 Hotel Suma          Hotel
# 432                           Josh Guest House    Guest House
# 433                     OYO 3836 Vedanta Villa          Hotel
# ...

# %%
df.to_csv('hotel_balinusa_new.csv', index=True, encoding='utf-8')

# %%
fasilitas = [
    "InDOnesia CARE",
    "tiket CLEAN",
    "Kolam Renang",
    "WiFi",
    "Parkir",
    "Restoran",
    "Resepsionis 24 Jam",
    "Lift",
    "AC",
    "Pusat Kebugaran",
    "Antar Jemput Bandara",
    "Fasilitas Rapat",
    "Bukti Vaksin Covid-19",
    "Pet-friendly",
    "Perlengkapan BBQ"
]

# %%
facilities_id = []
hotel_id = []
id_hotel = 431

for i in range(0, len(link_hotel)):
  url=link_hotel[i]
  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):
    room_price = a.findAll('div', attrs={'class':'room-price'})

    if len(room_price) > 0:
      for b in soup.findAll('div', attrs={'class':'card pdp-card facility-list'}):

        dunno = b.find('div', attrs={'class' : 'group-content'})

        label_div = dunno.findAll('div', attrs={'class' : 'facility-label'})
        # print(label_div)
        for c in range(len(label_div)):
          for d in range (len(fasilitas)):
            if label_div[c].text == fasilitas [d]:
              hotel_id.append(id_hotel)

              facilities_id.append(d + 1)
      
      id_hotel += 1

# %%
df = pd.DataFrame(list(zip(facilities_id, hotel_id)), columns =['list_fasil_id', 'hotel_id']) 
df
# Out:
#      list_fasil_id  hotel_id
# 0                2       431
# 1                3       431
# 2                4       431
# 3                5       431
# 4                6       431
# ..             ...       ...
# 873              5       574
# 874              4       575
# 875              2       576
# 876              4       576
# 877              5       576
#
# [878 rows x 2 columns]

# %%
df.to_csv('fasil_balinusa_new.csv', index=False, encoding='utf-8')

# %%
# df = pd.DataFrame({'Min Price' : min(priceHotel), 'Max Price': max(priceHotel)}, index = [0])
# df.to_csv('hotel-1.csv', index=True, encoding='utf-8')
# df

##

# if wifi in facil:
    #   facil = wifi
# else:
    #   facil = ''

##
# long = map_link.split("|")
# print(long)
