checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-2634-griya-birowo-syariah-401001610506420515?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/gubuk-asmoro-nglolang-310001603224126593?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/the-new-orlinds-guest-house-109001536321532999?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-barokah-302001581927309364?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/penginapan-putra-darma-405001621755910469?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",

    #Kalasan
    f"https://www.tiket.com/hotel/indonesia/premier-guest-house-309001599646510806?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/spot-on-2754-miyagi-guesthouse-301001578909619919?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-adisucipto-airport-3-108001534521346742?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-91075-sambisari-residence-syariah-504001649144321221?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/reddoorz-near-terminal-a-adisucipto-airport-206001559549841731?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/oyo-1355-griya-wismono-homestay-208001565242206786?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/omah-kebon-kalasan-303001583409762036?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/premier-guest-house-yogyakarta-412001638945252557?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/homestay-damandiri-prambanan-syariah-503001647489863845?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    f"https://www.tiket.com/hotel/indonesia/cozy-stay-hotel-509001662301172092?checkin={check_in}&checkout={check_out}&room=1&adult=1&soldOut=false",
    
]

# %%
facilities_id = []
hotel_id = []
id_hotel = 349

for i in range(0, len(link_hotel)):
  url=link_hotel[i]
  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):
    room_price = a.findAll('div', attrs={'class':'room-price'})

    if len(room_price):
      for b in soup.findAll('div', attrs={'class':'card pdp-card facility-list'}):

        dunno = b.find('div', attrs={'class' : 'group-content'})

        label_div = dunno.findAll('div', attrs={'class' : 'facility-label'})
        # print(label_div)
        for c in range(len(label_div)):
          for d in range (len(fasilitas)):
            if label_div[c].text == fasilitas [d]:
              hotel_id.append(id_hotel)

              facilities_id.append(d + 1)
      
      id_hotel += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\College\final-project\Datasets\Scrap_Hotel\scrap-facilDatabase-tiket.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap-facilDatabase-tiket.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> url=link_hotel[i]
#       <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap-facilDatabase-tiket.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> # print(url)
# ----> <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap-facilDatabase-tiket.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> req=requests.get(url)
#       <a href='vscode-notebook-cell:/d%3A/College/final-project/Datasets/Scrap_Hotel/scrap-facilDatabase-tiket.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> content=req.text
# ...

# %%
df = pd.DataFrame(list(zip(facilities_id, hotel_id)), columns =['list_fasil_id', 'hotel_id']) 
df
# Out:
#      list_fasil_id  hotel_id
# 0                2       251
# 1                4       251
# 2                5       251
# 3                9       251
# 4                2       252
# ..             ...       ...
# 483              3       348
# 484              4       348
# 485              5       348
# 486              7       348
# 487              9       348
#
# [488 rows x 2 columns]

# %%
df.to_csv('db_fasilitas_diy.csv', index=False, encoding='utf-8')
