checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/teratai-biru-river-camping-ground-504001649747826037?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/ida-homestay-redpartner-412001640804438481?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",

    #Gunung Kidul
    "https://www.tiket.com/hotel/indonesia/dea-lokha-hotel-311001604980816094?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/alzara-hotel-108001534490333779?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/oyo-life-3003-wisma-handayani-syariah-504001650526229915?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/kopilimo-cafe-homestay-108001534490377674?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/omah-sundak-homestay-108001534490373788?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/rock-garden-homestay-resto-212001577347218173?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/hotel-kukup-indah-412001639978972826?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/oyo-2634-griya-birowo-syariah-401001610506420515?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/gubuk-asmoro-nglolang-310001603224126593?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/the-new-orlinds-guest-house-109001536321532999?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/penginapan-barokah-302001581927309364?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/penginapan-putra-darma-405001621755910469?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",

    #Kalasan
    "https://www.tiket.com/hotel/indonesia/premier-guest-house-309001599646510806?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/spot-on-2754-miyagi-guesthouse-301001578909619919?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-near-adisucipto-airport-3-108001534521346742?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/oyo-91075-sambisari-residence-syariah-504001649144321221?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/reddoorz-near-terminal-a-adisucipto-airport-206001559549841731?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/oyo-1355-griya-wismono-homestay-208001565242206786?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/omah-kebon-kalasan-303001583409762036?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/premier-guest-house-yogyakarta-412001638945252557?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/homestay-damandiri-prambanan-syariah-503001647489863845?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    "https://www.tiket.com/hotel/indonesia/cozy-stay-hotel-509001662301172092?checkin=2022-10-11&checkout=2022-10-12&room=1&adult=1&soldOut=false",
    
]

# %%
facilities_id = []
hotel_id = []
id_hotel = 380

for i in range(0, len(link_hotel)):
  url=link_hotel[i]
  # print(url)
  req=requests.get(url)
  content=req.text

  soup=BeautifulSoup(content)

  for a in soup.findAll('div', attrs={'class':'hotel-detail__container'}):
    room_price = a.findAll('div', attrs={'class':'room-price'})

    if len(room_price) > 0:
      for b in soup.findAll('div', attrs={'class':'card pdp-card facility-list'}):

        dunno = b.find('div', attrs={'class' : 'group-content'})

        label_div = dunno.findAll('div', attrs={'class' : 'facility-label'})
        # print(label_div)
        for c in range(len(label_div)):
          for d in range (len(fasilitas)):
            if label_div[c].text == fasilitas [d]:
              hotel_id.append(id_hotel)

              facilities_id.append(d + 1)
      
      id_hotel += 1

# %%
df = pd.DataFrame(list(zip(facilities_id, hotel_id)), columns =['list_fasil_id', 'hotel_id']) 
df
# Out:
#      list_fasil_id  hotel_id
# 0                2       380
# 1                4       380
# 2                5       380
# 3                7       380
# 4                5       381
# ..             ...       ...
# 206              7       427
# 207              4       428
# 208              9       428
# 209              4       429
# 210              4       430
#
# [211 rows x 2 columns]

# %%
df.to_csv('fasil_diy_new.csv', index=False, encoding='utf-8')
